# %% [markdown]
# # Groupby
#
# files needed = ('Most-Recent-Cohorts-Scorecard-Elements.csv')
#
# We often want to know how groups differ. Do workers with econ degrees make more than workers with history degrees? Do men live longer than women? Does it matter how much education you have?
#
# Pandas provides the `groupby( )` method to ease computing statistics by group ([docs](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html)). This kind of method shows up in many data-oriented computing languages and packages. The idea is summed up as
#
# > split-apply-combine
#
# Here is the canonical [illustration](https://www.oreilly.com/library/view/learning-pandas/9781783985128/ch09s02.html). The big idea is to
# 1. **Split** the data up into groups. The groups are defined by *key* variables.
# 2. **Apply** some method or function to each group: mean, std, max, etc. This returns a smaller bit of data, often just one number.
# 3. **Combine** the results of the 'apply' from each group into a new data structure.

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('precision', 3)       # this tells pandas to print out 3 decimal places when we print a DataFrame

# %% [markdown]
# ## College Scorecard
# Let's take this opportunity to learn about a new dataset: [The College Scorecard](https://collegescorecard.ed.gov/data/). The data are compiled by the Dept. of Education to help students evaluate higher education institutions. The data are very well documented and include such juicy variables as: prices, after program debt levels, earnings, completion rates, information about student outcomes by family income and other demographic variables.
#
# We will be working off of the 'most recent data' file. It is in our shared folder, but you can also get it from [here](https://ed-public-download.app.cloud.gov/downloads/Most-Recent-Cohorts-Scorecard-Elements.csv).

# %%
colscd = pd.read_csv('college_scorecard/Most-Recent-Cohorts-Scorecard-Elements.csv')
colscd.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR                    INSTURL  \
# 0     AL              www.aamu.edu/
# 1     AL                www.uab.edu
# 2     AL  www.amridgeuniversity.edu
# 3     AL                www.uah.edu
# 4     AL              www.alasu.edu
#
#                                               NPCURL  HCM2  PREDDEG  \
# 0      www2.aamu.edu/scripts/netpricecalc/npcalc.htm     0        3
# 1           uab.studentaidcalculator.com/survey.aspx     0        3
# 2                   www2.amridgeuniversity.edu:9091/     0        3
# 3                                    finaid.uah.edu/     0        3
# 4  www.alasu.edu/cost-aid/forms/calculator/index....     0        3
#
#           ...          PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GT_25K_P6  \
# 0         ...             0.767    0.086            31000      0.453
# 1         ...             0.518    0.236            41200      0.669
# 2         ...             0.844    0.857            39600      0.658
# 3         ...             0.431    0.226            46700      0.685
# 4         ...             0.811    0.097            27700      0.393
#
#    GT_28K_P6  GRAD_DEBT_MDN_SUPP  GRAD_DEBT_MDN10YR_SUPP  RPY_3YR_RT_SUPP  \
# 0      0.431               32750         348.16551225731     0.2531554273
# 1      0.631               21833        232.106797835537      0.513963161
# 2      0.542               22890        243.343773299842     0.2307692308
# 3      0.649               22647        240.760438353933     0.5485090298
# 4      0.351               31500        334.876752247489     0.2185867473
#
#    C150_L4_POOLED_SUPP  C150_4_POOLED_SUPP
# 0                  NaN              0.2913
# 1                  NaN              0.5384
# 2                  NaN   PrivacySuppressed
# 3                  NaN              0.4905
# 4                  NaN              0.2475
#
# [5 rows x 124 columns]

# %% [markdown]
# This dataset is too big for our needs. Let's rename the variables to something easier to understand and keep just a few variables that look interesting.

# %%
colscd = colscd.rename(columns = {'CONTROL':'ownership', 'INSTNM':'name', 'STABBR':'state', 'PREDDEG':'type', 'SATVRMID':'sat_read_med', 
                      'SATMTMID':'sat_math_med', 'SATWRMID':'sat_write_med', 'PCIP24':'sh_las', 'PCIP51':'sh_bus',
                     'PCIP11':'sh_cs', 'MD_EARN_WNE_P10':'earn_10', 'GRAD_DEBT_MDN_SUPP':'debt_at_grad'})

# %%
cols_to_keep = ['name', 'state', 'ownership', 'type','sat_read_med',  'sat_math_med', 'sat_write_med',
                'sh_las', 'sh_bus', 'sh_cs', 'earn_10', 'debt_at_grad']

colscd = colscd[cols_to_keep]

colscd.head()
# Out:
#                                   name state  ownership  type  sat_read_med  \
# 0             Alabama A & M University    AL          1     3         425.0
# 1  University of Alabama at Birmingham    AL          1     3         560.0
# 2                   Amridge University    AL          2     3           NaN
# 3  University of Alabama in Huntsville    AL          1     3         590.0
# 4             Alabama State University    AL          1     3         415.0
#
#    sat_math_med  sat_write_med  sh_las  sh_bus  sh_cs earn_10 debt_at_grad
# 0         420.0          414.0   0.066   0.000  0.040   31000        32750
# 1         575.0            NaN   0.013   0.250  0.013   41200        21833
# 2           NaN            NaN   0.089   0.000  0.000   39600        22890
# 3         610.0            NaN   0.000   0.191  0.050   46700        22647
# 4         410.0            NaN   0.000   0.143  0.050   27700        31500

# %% [markdown]
# The ownership and type variables are coded as integers. I would rather they were easy to understand.

# %%
type_codes = {0:'na', 1:'cert', 2:'asc', 3:'bach', 4:'grad_only'}
colscd['type'] = colscd['type'].replace(type_codes)

own_codes = {1:'Public', 2:'Private nonprofit', 3:'Private profit'}
colscd['ownership'] = colscd['ownership'].replace(own_codes)
colscd.head()
# Out:
#                                   name state          ownership  type  \
# 0             Alabama A & M University    AL             Public  bach
# 1  University of Alabama at Birmingham    AL             Public  bach
# 2                   Amridge University    AL  Private nonprofit  bach
# 3  University of Alabama in Huntsville    AL             Public  bach
# 4             Alabama State University    AL             Public  bach
#
#    sat_read_med  sat_math_med  sat_write_med  sh_las  sh_bus  sh_cs earn_10  \
# 0         425.0         420.0          414.0   0.066   0.000  0.040   31000
# 1         560.0         575.0            NaN   0.013   0.250  0.013   41200
# 2           NaN           NaN            NaN   0.089   0.000  0.000   39600
# 3         590.0         610.0            NaN   0.000   0.191  0.050   46700
# 4         415.0         410.0            NaN   0.000   0.143  0.050   27700
#
#   debt_at_grad
# 0        32750
# 1        21833
# 2        22890
# 3        22647
# 4        31500

# %% [markdown]
# Set the index to the university name.

# %%
colscd.set_index('name', inplace=True)

# %% [markdown]
# How do we look?

# %%
colscd.loc['University of Wisconsin-Madison']
# Out:
# state                WI
# ownership        Public
# type               bach
# sat_read_med        610
# sat_math_med        700
# sat_write_med       640
# sh_las                0
# sh_bus           0.0646
# sh_cs            0.0289
# earn_10           56200
# debt_at_grad      22241
# Name: University of Wisconsin-Madison, dtype: object

# %% [markdown]
# Unless I read the documentation wrong, (or made some other mistake) this says UW didn't give out an liberal arts degrees. I doubt that it true...
#
# One last check before we get to work.

# %%
colscd.dtypes
# Out:
# state             object
# ownership         object
# type              object
# sat_read_med     float64
# sat_math_med     float64
# sat_write_med    float64
# sh_las           float64
# sh_bus           float64
# sh_cs            float64
# earn_10           object
# debt_at_grad      object
# dtype: object

# %% [markdown]
# Doh! looks like the earnings and debt came in as objects instead of floats.
#
# The culprit is the 'PrivacySuppressed' flag. We could have told `read_csv` about this if we knew in advance.
#
# Instead, let's practice `to_numeric( )` which tries to convert a column to numeric values. I pass the parameter `error='coerce'` to tell the method to set anything it cannot convert to a NaN.

# %%
colscd['earn_10'] = pd.to_numeric(colscd['earn_10'], errors='coerce')
colscd['debt_at_grad'] = pd.to_numeric(colscd['debt_at_grad'], errors='coerce')
colscd.dtypes
# Out:
# state             object
# ownership         object
# type              object
# sat_read_med     float64
# sat_math_med     float64
# sat_write_med    float64
# sh_las           float64
# sh_bus           float64
# sh_cs            float64
# earn_10          float64
# debt_at_grad     float64
# dtype: object

# %% [markdown]
# ### groupby( )
# We pass groupby a 'key' which tells the method which variable to, well, group by. This is the **split** step.

# %%
colscd_grouped = colscd.groupby('state')

# %% [markdown]
# What is `colscd_grouped`?

# %%
print(type(colscd_grouped))
# Out:
# <class 'pandas.core.groupby.groupby.DataFrameGroupBy'>

# %% [markdown]
# A DataFrameGroupBy object. This is basically a DataFrame + the grouping information.
#
# What does it look like?

# %%
colscd_grouped.head()
# Out:
#                                                  state          ownership  \
# name
# Alabama A & M University                            AL             Public
# University of Alabama at Birmingham                 AL             Public
# Amridge University                                  AL  Private nonprofit
# University of Alabama in Huntsville                 AL             Public
# Alabama State University                            AL             Public
# Prince Institute-Southeast                          IL     Private profit
# University of Alaska Anchorage                      AK             Public
# Alaska Bible College                                AK  Private nonprofit
# University of Alaska Fairbanks                      AK             Public
# University of Alaska Southeast                      AK             Public
# Alaska Pacific University                           AK  Private nonprofit
# Charter College                                     WA     Private profit
# Empire Beauty School-Tucson                         AZ     Private profit
# Thunderbird School of Global Management             AZ             Public
# American Institute of Trucking                      AZ     Private profit
# Carrington College-Phoenix North                    AZ     Private profit
# Carrington College-Mesa                             AZ     Private profit
# Pima Medical Institute-Albuquerque                  NM     Private profit
# University of Arkansas at Little Rock               AR             Public
# University of Arkansas for Medical Sciences         AR             Public
# Arkansas Baptist College                            AR  Private nonprofit
# Arkansas Beauty School-Little Rock                  AR     Private profit
# Arkansas Beauty College                             AR     Private profit
# Academy of Art University                           CA     Private profit
# Academy of Chinese Culture and Health Sciences      CA  Private nonprofit
# The Academy of Radio and TV Broadcasting            CA     Private profit
# Avalon School of Cosmetology-Alameda                CA     Private profit
# College of Alameda                                  CA             Public
# Walden University                                   MN     Private profit
# The Salon Professional Academy-Grand Junction       CO     Private profit
# ...                                                ...                ...
# Bellevue College                                    WA             Public
# Alderson Broaddus University                        WV  Private nonprofit
# Appalachian Bible College                           WV  Private nonprofit
# B M Spurr School of Practical Nursing               WV  Private nonprofit
# Ben Franklin Career Center                          WV             Public
# Advanced Institute of Hair Design-Glendale          WI     Private profit
# VICI Beauty School                                  WI     Private profit
# Alverno College                                     WI  Private nonprofit
# Madison Area Technical College                      WI             Public
# Bellin College                                      WI  Private nonprofit
# Casper College                                      WY             Public
# Central Wyoming College                             WY             Public
# Eastern Wyoming College                             WY             Public
# Laramie County Community College                    WY             Public
# Northwest College                                   WY             Public
# American Samoa Community College                    AS             Public
# Guam Community College                              GU             Public
# University of Guam                                  GU             Public
# Northern Marianas College                           MP             Public
# Institute of Beauty Careers                         PR     Private profit
# Educational Technical College-Recinto de Bayamon    PR     Private profit
# American University of Puerto Rico                  PR  Private nonprofit
# American University of Puerto Rico                  PR  Private nonprofit
# American Educational College                        PR     Private profit
# College of Micronesia-FSM                           FM             Public
# Palau Community College                             PW             Public
# University of the Virgin Islands                    VI             Public
# College of the Marshall Islands                     MH             Public
# Pacific Islands University                          GU  Private nonprofit
# University of the Virgin Islands-Albert A. Sheen    VI             Public
#
#                                                        type  sat_read_med  \
# name
# Alabama A & M University                               bach         425.0
# University of Alabama at Birmingham                    bach         560.0
# Amridge University                                     bach           NaN
# University of Alabama in Huntsville                    bach         590.0
# Alabama State University                               bach         415.0
# Prince Institute-Southeast                              asc           NaN
# University of Alaska Anchorage                         bach           NaN
# Alaska Bible College                                   cert           NaN
# University of Alaska Fairbanks                         bach         540.0
# University of Alaska Southeast                         cert           NaN
# Alaska Pacific University                              bach           NaN
# Charter College                                        cert           NaN
# Empire Beauty School-Tucson                            cert           NaN
# Thunderbird School of Global Management           grad_only           NaN
# American Institute of Trucking                         cert           NaN
# Carrington College-Phoenix North                       cert           NaN
# Carrington College-Mesa                                cert           NaN
# Pima Medical Institute-Albuquerque                     cert           NaN
# University of Arkansas at Little Rock                  bach         490.0
# University of Arkansas for Medical Sciences            bach           NaN
# Arkansas Baptist College                                asc           NaN
# Arkansas Beauty School-Little Rock                     cert           NaN
# Arkansas Beauty College                                cert           NaN
# Academy of Art University                              bach           NaN
# Academy of Chinese Culture and Health Sciences    grad_only           NaN
# The Academy of Radio and TV Broadcasting               cert           NaN
# Avalon School of Cosmetology-Alameda                   cert           NaN
# College of Alameda                                     cert           NaN
# Walden University                                      bach           NaN
# The Salon Professional Academy-Grand Junction          cert           NaN
# ...                                                     ...           ...
# Bellevue College                                        asc           NaN
# Alderson Broaddus University                           bach         470.0
# Appalachian Bible College                              bach         518.0
# B M Spurr School of Practical Nursing                  cert           NaN
# Ben Franklin Career Center                             cert           NaN
# Advanced Institute of Hair Design-Glendale             cert           NaN
# VICI Beauty School                                     cert           NaN
# Alverno College                                        bach           NaN
# Madison Area Technical College                         cert           NaN
# Bellin College                                         bach           NaN
# Casper College                                          asc           NaN
# Central Wyoming College                                 asc           NaN
# Eastern Wyoming College                                 asc           NaN
# Laramie County Community College                        asc           NaN
# Northwest College                                       asc           NaN
# American Samoa Community College                        asc           NaN
# Guam Community College                                  asc           NaN
# University of Guam                                     bach           NaN
# Northern Marianas College                               asc           NaN
# Institute of Beauty Careers                            cert           NaN
# Educational Technical College-Recinto de Bayamon       cert           NaN
# American University of Puerto Rico                     bach           NaN
# American University of Puerto Rico                     bach           NaN
# American Educational College                           cert           NaN
# College of Micronesia-FSM                               asc           NaN
# Palau Community College                                 asc           NaN
# University of the Virgin Islands                       bach         420.0
# College of the Marshall Islands                         asc           NaN
# Pacific Islands University                              asc           NaN
# University of the Virgin Islands-Albert A. Sheen         na           NaN
#
#                                                   sat_math_med  sat_write_med  \
# name
# Alabama A & M University                                 420.0          414.0
# University of Alabama at Birmingham                      575.0            NaN
# Amridge University                                         NaN            NaN
# University of Alabama in Huntsville                      610.0            NaN
# Alabama State University                                 410.0            NaN
# Prince Institute-Southeast                                 NaN            NaN
# University of Alaska Anchorage                             NaN            NaN
# Alaska Bible College                                       NaN            NaN
# University of Alaska Fairbanks                           535.0          510.0
# University of Alaska Southeast                             NaN            NaN
# Alaska Pacific University                                  NaN          455.0
# Charter College                                            NaN            NaN
# Empire Beauty School-Tucson                                NaN            NaN
# Thunderbird School of Global Management                    NaN            NaN
# American Institute of Trucking                             NaN            NaN
# Carrington College-Phoenix North                           NaN            NaN
# Carrington College-Mesa                                    NaN            NaN
# Pima Medical Institute-Albuquerque                         NaN            NaN
# University of Arkansas at Little Rock                    505.0          475.0
# University of Arkansas for Medical Sciences                NaN            NaN
# Arkansas Baptist College                                   NaN            NaN
# Arkansas Beauty School-Little Rock                         NaN            NaN
# Arkansas Beauty College                                    NaN            NaN
# Academy of Art University                                  NaN            NaN
# Academy of Chinese Culture and Health Sciences             NaN            NaN
# The Academy of Radio and TV Broadcasting                   NaN            NaN
# Avalon School of Cosmetology-Alameda                       NaN            NaN
# College of Alameda                                         NaN            NaN
# Walden University                                          NaN            NaN
# The Salon Professional Academy-Grand Junction              NaN            NaN
# ...                                                        ...            ...
# Bellevue College                                           NaN            NaN
# Alderson Broaddus University                             480.0          450.0
# Appalachian Bible College                                404.0          495.0
# B M Spurr School of Practical Nursing                      NaN            NaN
# Ben Franklin Career Center                                 NaN            NaN
# Advanced Institute of Hair Design-Glendale                 NaN            NaN
# VICI Beauty School                                         NaN            NaN
# Alverno College                                            NaN          498.0
# Madison Area Technical College                             NaN            NaN
# Bellin College                                             NaN            NaN
# Casper College                                             NaN            NaN
# Central Wyoming College                                    NaN            NaN
# Eastern Wyoming College                                    NaN            NaN
# Laramie County Community College                           NaN            NaN
# Northwest College                                          NaN            NaN
# American Samoa Community College                           NaN            NaN
# Guam Community College                                     NaN            NaN
# University of Guam                                         NaN            NaN
# Northern Marianas College                                  NaN            NaN
# Institute of Beauty Careers                                NaN            NaN
# Educational Technical College-Recinto de Bayamon           NaN            NaN
# American University of Puerto Rico                         NaN            NaN
# American University of Puerto Rico                         NaN            NaN
# American Educational College                               NaN            NaN
# College of Micronesia-FSM                                  NaN            NaN
# Palau Community College                                    NaN            NaN
# University of the Virgin Islands                         382.0          410.0
# College of the Marshall Islands                            NaN            NaN
# Pacific Islands University                                 NaN            NaN
# University of the Virgin Islands-Albert A. Sheen           NaN            NaN
#
#                                                   sh_las  sh_bus  sh_cs  \
# name
# Alabama A & M University                           0.066   0.000  0.040
# University of Alabama at Birmingham                0.013   0.250  0.013
# Amridge University                                 0.089   0.000  0.000
# University of Alabama in Huntsville                0.000   0.191  0.050
# Alabama State University                           0.000   0.143  0.050
# Prince Institute-Southeast                         0.000   0.300  0.000
# University of Alaska Anchorage                     0.123   0.217  0.023
# Alaska Bible College                               0.000   0.000  0.000
# University of Alaska Fairbanks                     0.074   0.158  0.021
# University of Alaska Southeast                     0.081   0.181  0.004
# Alaska Pacific University                          0.061   0.000  0.000
# Charter College                                    0.000   0.669  0.027
# Empire Beauty School-Tucson                        0.000   0.000  0.000
# Thunderbird School of Global Management              NaN     NaN    NaN
# American Institute of Trucking                     0.000   0.000  0.000
# Carrington College-Phoenix North                   0.000   1.000  0.000
# Carrington College-Mesa                            0.000   1.000  0.000
# Pima Medical Institute-Albuquerque                 0.000   1.000  0.000
# University of Arkansas at Little Rock              0.088   0.249  0.029
# University of Arkansas for Medical Sciences        0.000   1.000  0.000
# Arkansas Baptist College                           0.585   0.000  0.000
# Arkansas Beauty School-Little Rock                 0.000   0.000  0.000
# Arkansas Beauty College                            0.000   0.000  0.000
# Academy of Art University                          0.000   0.000  0.051
# Academy of Chinese Culture and Health Sciences       NaN     NaN    NaN
# The Academy of Radio and TV Broadcasting           0.000   0.000  0.000
# Avalon School of Cosmetology-Alameda               0.000   0.000  0.000
# College of Alameda                                 0.467   0.040  0.007
# Walden University                                  0.000   0.555  0.030
# The Salon Professional Academy-Grand Junction      0.000   0.000  0.000
# ...                                                  ...     ...    ...
# Bellevue College                                   0.570   0.108  0.085
# Alderson Broaddus University                       0.000   0.248  0.039
# Appalachian Bible College                          0.000   0.000  0.000
# B M Spurr School of Practical Nursing              0.000   1.000  0.000
# Ben Franklin Career Center                         0.000   0.036  0.000
# Advanced Institute of Hair Design-Glendale         0.000   0.000  0.000
# VICI Beauty School                                 0.000   0.000  0.000
# Alverno College                                    0.142   0.356  0.010
# Madison Area Technical College                     0.097   0.522  0.056
# Bellin College                                     0.000   1.000  0.000
# Casper College                                     0.109   0.339  0.008
# Central Wyoming College                            0.041   0.156  0.003
# Eastern Wyoming College                            0.172   0.112  0.000
# Laramie County Community College                   0.094   0.311  0.039
# Northwest College                                  0.157   0.182  0.000
# American Samoa Community College                   0.423   0.146  0.000
# Guam Community College                             0.112   0.144  0.041
# University of Guam                                 0.000   0.049  0.032
# Northern Marianas College                          0.357   0.097  0.000
# Institute of Beauty Careers                        0.000   0.134  0.000
# Educational Technical College-Recinto de Bayamon   0.000   0.857  0.000
# American University of Puerto Rico                 0.017   0.000  0.052
# American University of Puerto Rico                 0.018   0.000  0.097
# American Educational College                       0.000   0.196  0.014
# College of Micronesia-FSM                          0.091   0.101  0.034
# Palau Community College                            0.064   0.143  0.048
# University of the Virgin Islands                   0.004   0.060  0.036
# College of the Marshall Islands                    0.380   0.124  0.000
# Pacific Islands University                         0.857   0.000  0.000
# University of the Virgin Islands-Albert A. Sheen     NaN     NaN    NaN
#
#                                                    earn_10  debt_at_grad
# name
# Alabama A & M University                           31000.0       32750.0
# University of Alabama at Birmingham                41200.0       21833.0
# Amridge University                                 39600.0       22890.0
# University of Alabama in Huntsville                46700.0       22647.0
# Alabama State University                           27700.0       31500.0
# Prince Institute-Southeast                             NaN           NaN
# University of Alaska Anchorage                     45400.0       17833.5
# Alaska Bible College                                   NaN           NaN
# University of Alaska Fairbanks                     38700.0       15000.0
# University of Alaska Southeast                     36000.0       16000.0
# Alaska Pacific University                          40200.0       19500.0
# Charter College                                    39800.0       14875.0
# Empire Beauty School-Tucson                        20300.0       11766.0
# Thunderbird School of Global Management           118000.0       20000.0
# American Institute of Trucking                     33400.0        6002.0
# Carrington College-Phoenix North                   25400.0        9500.0
# Carrington College-Mesa                            25400.0        9500.0
# Pima Medical Institute-Albuquerque                 28800.0        8708.0
# University of Arkansas at Little Rock              34900.0       19750.0
# University of Arkansas for Medical Sciences        61000.0       14000.0
# Arkansas Baptist College                           21800.0       29750.0
# Arkansas Beauty School-Little Rock                 14000.0        6333.0
# Arkansas Beauty College                                NaN           NaN
# Academy of Art University                          38600.0       35688.0
# Academy of Chinese Culture and Health Sciences         NaN           NaN
# The Academy of Radio and TV Broadcasting           31000.0        9500.0
# Avalon School of Cosmetology-Alameda               20000.0        6332.0
# College of Alameda                                 34200.0           NaN
# Walden University                                  50100.0       24028.0
# The Salon Professional Academy-Grand Junction          NaN       11817.5
# ...                                                    ...           ...
# Bellevue College                                   43500.0       11000.0
# Alderson Broaddus University                       40400.0       26002.0
# Appalachian Bible College                          26700.0       14000.0
# B M Spurr School of Practical Nursing                  NaN           NaN
# Ben Franklin Career Center                         18700.0           NaN
# Advanced Institute of Hair Design-Glendale         23400.0        9642.0
# VICI Beauty School                                 23400.0        9642.0
# Alverno College                                    38800.0       31000.0
# Madison Area Technical College                     36500.0       12250.0
# Bellin College                                     58600.0       15000.0
# Casper College                                     35500.0        8133.0
# Central Wyoming College                            28400.0        6500.0
# Eastern Wyoming College                            28500.0        6500.0
# Laramie County Community College                   34600.0       10431.0
# Northwest College                                  30000.0       10145.0
# American Samoa Community College                   22300.0           NaN
# Guam Community College                             23500.0           NaN
# University of Guam                                 30100.0       19924.0
# Northern Marianas College                          20700.0           NaN
# Institute of Beauty Careers                        13700.0           NaN
# Educational Technical College-Recinto de Bayamon   15200.0           NaN
# American University of Puerto Rico                 21700.0        4300.0
# American University of Puerto Rico                 21700.0        4300.0
# American Educational College                       15100.0           NaN
# College of Micronesia-FSM                          19500.0           NaN
# Palau Community College                                NaN           NaN
# University of the Virgin Islands                   32000.0       13761.5
# College of the Marshall Islands                        NaN           NaN
# Pacific Islands University                             NaN           NaN
# University of the Virgin Islands-Albert A. Sheen   32000.0       13761.5
#
# [270 rows x 11 columns]

# %%
colscd.dtypes
# Out:
# state             object
# ownership         object
# type              object
# sat_read_med     float64
# sat_math_med     float64
# sat_write_med    float64
# sh_las           float64
# sh_bus           float64
# sh_cs            float64
# earn_10          float64
# debt_at_grad     float64
# dtype: object

# %% [markdown]
# Looks just like a regular DataFrame. It also looks like `head()` doesn't work for DataFrameGroupedBy.

# %% [markdown]
# ### Aggregating by group
# A major use of groupby is to perform some kind of aggregation. This is the **apply** and **combine** step. Let's take the grouped data and compute some means.

# %%
all_means = colscd_grouped.mean()  # apply the mean operator to the grouped data

print(type(all_means))             # what do we get back?
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Ah, a DataFrame. We know what to do with that. 
all_means.head(10)
# Out:
#        sat_read_med  sat_math_med  sat_write_med  sh_las  sh_bus  sh_cs  \
# state
# AK          540.000       535.000        482.500   0.052   0.174  0.017
# AL          508.208       507.208        504.200   0.097   0.243  0.021
# AR          496.500       514.125        464.200   0.112   0.207  0.014
# AS              NaN           NaN            NaN   0.423   0.146  0.000
# AZ          534.667       540.333        505.000   0.071   0.280  0.025
# CA          547.451       556.239        570.540   0.067   0.270  0.022
# CO          535.643       538.071        570.000   0.046   0.285  0.027
# CT          513.214       515.571        518.167   0.069   0.284  0.019
# DC          600.600       595.000        605.000   0.015   0.134  0.070
# DE          481.667       485.000        472.333   0.012   0.318  0.015
#
#          earn_10  debt_at_grad
# state
# AK     37800.000     13711.500
# AL     31343.590     19457.359
# AR     28166.667     15130.530
# AS     22300.000           NaN
# AZ     33351.613     14094.925
# CA     37192.998     14372.486
# CO     33270.130     16809.221
# CT     42170.149     15554.923
# DC     47568.750     23521.088
# DE     36263.636     14817.941

# %% [markdown]
# When we used mean() one the grouped data, it **applied** the mean method to each group, which creates one number per group (for each column). It then **combined** the means into a DataFrame, one number per group per column. Nice.
#
# Notice that the categorical data (name, state, type) have been dropped.
#
# Here we can see the result of pd.set_option('precision'). The output is limited to 3 decimal places.

# %% [markdown]
# Computing the grouped data first helped us understand what was happening, but we can do the whole split-apply-combine in one step. One simple line of code.

# %%
all_means = colscd.groupby('state').mean()
all_means.head(10)
# Out:
#        sat_read_med  sat_math_med  sat_write_med  sh_las  sh_bus  sh_cs  \
# state
# AK          540.000       535.000        482.500   0.052   0.174  0.017
# AL          508.208       507.208        504.200   0.097   0.243  0.021
# AR          496.500       514.125        464.200   0.112   0.207  0.014
# AS              NaN           NaN            NaN   0.423   0.146  0.000
# AZ          534.667       540.333        505.000   0.071   0.280  0.025
# CA          547.451       556.239        570.540   0.067   0.270  0.022
# CO          535.643       538.071        570.000   0.046   0.285  0.027
# CT          513.214       515.571        518.167   0.069   0.284  0.019
# DC          600.600       595.000        605.000   0.015   0.134  0.070
# DE          481.667       485.000        472.333   0.012   0.318  0.015
#
#          earn_10  debt_at_grad
# state
# AK     37800.000     13711.500
# AL     31343.590     19457.359
# AR     28166.667     15130.530
# AS     22300.000           NaN
# AZ     33351.613     14094.925
# CA     37192.998     14372.486
# CO     33270.130     16809.221
# CT     42170.149     15554.923
# DC     47568.750     23521.088
# DE     36263.636     14817.941

# %% [markdown]
# ### groupby( ) with many keys
# Can we group by several keys? You know we can. Let's compute the medians this time.

# %%
sat_medians = colscd.groupby(['ownership','type']).median()
sat_medians
# Out:
#                              sat_read_med  sat_math_med  sat_write_med  \
# ownership         type
# Private nonprofit asc               455.0         455.0          438.0
#                   bach              518.0         515.0          508.0
#                   cert              490.0         510.0          492.5
#                   grad_only         558.0         636.0            NaN
#                   na                  NaN           NaN            NaN
# Private profit    asc                 NaN           NaN            NaN
#                   bach              483.5         465.0          488.5
#                   cert                NaN           NaN            NaN
#                   grad_only           NaN           NaN            NaN
#                   na                  NaN           NaN            NaN
# Public            asc               455.0         454.0          420.0
#                   bach              509.0         517.5          490.0
#                   cert                NaN           NaN            NaN
#                   grad_only           NaN           NaN            NaN
#                   na                  NaN           NaN            NaN
#
#                              sh_las  sh_bus  sh_cs   earn_10  debt_at_grad
# ownership         type
# Private nonprofit asc         0.000   0.318  0.000   32400.0      18535.00
#                   bach        0.000   0.026  0.005   42600.0      25043.75
#                   cert        0.000   0.677  0.000   26800.0      10608.00
#                   grad_only   0.000   0.000  0.000   80250.0      20466.00
#                   na            NaN     NaN    NaN   38550.0      23340.00
# Private profit    asc         0.000   0.517  0.000   29200.0      21246.00
#                   bach        0.000   0.000  0.038   41400.0      30481.00
#                   cert        0.000   0.000  0.000   22300.0       9500.00
#                   grad_only     NaN     NaN    NaN   34500.0      30352.00
#                   na            NaN     NaN    NaN   32600.0      18254.00
# Public            asc         0.306   0.188  0.025   31400.0       9768.50
#                   bach        0.018   0.092  0.023   42950.0      21500.00
#                   cert        0.000   0.351  0.008   29100.0       9188.00
#                   grad_only   0.000   0.000  0.000  102100.0      21750.00
#                   na            NaN     NaN    NaN   34200.0      12000.00

# %% [markdown]
# Now we have a MultiIndexed DataFrame with the summary statistics, this time, the median.

# %% [markdown]
# ### gropuby( ) on a subset of columns
# We may not care about all the columns in our datset for a particular groupby. Taking a subset of columns is straightforward.
#
# Let's focus on the median SAT scores.

# %%
sat_medians = colscd.groupby(['ownership','type'])[['sat_read_med', 'sat_math_med', 'sat_write_med']].median()
sat_medians
# Out:
#                              sat_read_med  sat_math_med  sat_write_med
# ownership         type
# Private nonprofit asc               455.0         455.0          438.0
#                   bach              518.0         515.0          508.0
#                   cert              490.0         510.0          492.5
#                   grad_only         558.0         636.0            NaN
#                   na                  NaN           NaN            NaN
# Private profit    asc                 NaN           NaN            NaN
#                   bach              483.5         465.0          488.5
#                   cert                NaN           NaN            NaN
#                   grad_only           NaN           NaN            NaN
#                   na                  NaN           NaN            NaN
# Public            asc               455.0         454.0          420.0
#                   bach              509.0         517.5          490.0
#                   cert                NaN           NaN            NaN
#                   grad_only           NaN           NaN            NaN
#                   na                  NaN           NaN            NaN

# %% [markdown]
# The three ownership types all have institutions that predominately offer bachelors degrees. Let's grab that set of statistics.

# %%
bach_sat_med = sat_medians.xs('bach', level='type')         # xs() indexes data from a MultiIndex
bach_sat_med
# Out:
#                    sat_read_med  sat_math_med  sat_write_med
# ownership
# Private nonprofit         518.0         515.0          508.0
# Private profit            483.5         465.0          488.5
# Public                    509.0         517.5          490.0

# %% [markdown]
# How do the median SAT scores compare across public and private institutions?
#
# There are a few new plotting tricks here...

# %%
fig, ax = plt.subplots(1, 3, figsize=(21,6))

# Set up the color scheme. This makes it easier to fiddle with.
bar_color = 'red'
bar_alpha = 0.35

# Plot one SAT variable on each axes
ax[0].bar(bach_sat_med.index, bach_sat_med['sat_math_med'], color=bar_color, alpha=bar_alpha)
ax[1].bar(bach_sat_med.index, bach_sat_med['sat_read_med'], color=bar_color, alpha=bar_alpha)
ax[2].bar(bach_sat_med.index, bach_sat_med['sat_write_med'],color=bar_color, alpha=bar_alpha)

# Titles!
ax[0].set_title('SAT reading')
ax[1].set_title('SAT math')
ax[2].set_title('SAT writing')

# I am only setting the ylabel on the left-most. Save some non-data ink.
ax[0].set_ylabel('Median score')

# Set these common parameters by looping over the axes.
for a in ax:
    a.spines['top'].set_visible(False)
    a.spines['right'].set_visible(False)
    a.grid(axis='y', color='white')                # Still experimenting with this...
    a.xaxis.set_tick_params(length=0)              # Kill the xaxis ticks
    a.yaxis.set_tick_params(length=0)              # Kill the yaxis ticks
    
plt.show()

# %% [markdown]
# Interesting. Private for-profit institutions seem to have about the same quality of writing scores, a bit lower math scores and substantially lower reading scores. Once we fire up some stats model packages, we can do formal tests to see if they are significantly different.

# %% [markdown]
# ## Practice
#
# 1. Create a dataset with only public institutions. Name it `pub`

# %%
pub = colscd[colscd.ownership == "Public"]
pub.head()
# Out:
#                                     state ownership  type  sat_read_med  \
# name
# Alabama A & M University               AL    Public  bach         425.0
# University of Alabama at Birmingham    AL    Public  bach         560.0
# University of Alabama in Huntsville    AL    Public  bach         590.0
# Alabama State University               AL    Public  bach         415.0
# The University of Alabama              AL    Public  bach         550.0
#
#                                      sat_math_med  sat_write_med  sh_las  \
# name
# Alabama A & M University                    420.0          414.0   0.066
# University of Alabama at Birmingham         575.0            NaN   0.013
# University of Alabama in Huntsville         610.0            NaN   0.000
# Alabama State University                    410.0            NaN   0.000
# The University of Alabama                   555.0          540.0   0.000
#
#                                      sh_bus  sh_cs  earn_10  debt_at_grad
# name
# Alabama A & M University              0.000  0.040  31000.0       32750.0
# University of Alabama at Birmingham   0.250  0.013  41200.0       21833.0
# University of Alabama in Huntsville   0.191  0.050  46700.0       22647.0
# Alabama State University              0.143  0.050  27700.0       31500.0
# The University of Alabama             0.099  0.010  44500.0       23290.0

# %% [markdown]
# The `quantile( )` method computes quantiles from the data. (e.g., `quantile(0.5)` computes the median, or the the 50th quantile)
#
# 2. Let's look at a measure of the earnings spread for different institution types
#
#     a. Compute the 75th quantile for 'earn_10' for each 'type'.
#
#     b. Compute the 50th quantile for 'earn_10' for each 'type'.
#
#     c. Compute the 25th quantile for 'earn_10' for each 'type'.

# %%
pub_75 = pub.groupby("type")["earn_10"].quantile(.75)
pub_50 = pub.groupby("type")["earn_10"].quantile(.5)
pub_25 = pub.groupby("type")["earn_10"].quantile(.25)

# %% [markdown]
# 2d. For each type, compute the difference between the 75 percentile and the 25 percentile and divide it by the median.

# %%
dif = (pub_75 - pub_25) / pub_50
dif
# Out:
# type
# asc          0.197
# bach         0.264
# cert         0.268
# grad_only    0.917
# na           0.202
# Name: earn_10, dtype: float64

# %% [markdown]
# Wow, a lot of dispersion in the grad_only group. Let's practice some more.
#
#
#
# 3. How do reading and writing scores correlate?
#
#     a. Compute the median SAT reading and writing scores by state.

# %%
median_sat_read = pub.groupby("state")["sat_read_med"].median()
median_sat_write = pub.groupby("state")["sat_write_med"].median()

# %% [markdown]
# 3b. Create a scatter plot with the median reading score on the x axis and writing score on the y axis.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots()

ax.scatter(x = median_sat_read, y = median_sat_write, marker = "x")
ax.plot([400, 600], [400, 600], color = "black", alpha = .4)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_title("Scatter plot of median SAT reading vs. writing scores")
ax.set_xlabel("Median SAT Reading Score")
ax.set_ylabel("Median SAT Writing Score")

plt.show()

# %% [markdown]
# ### Working with quantiles

# %%
bus_quart = pd.cut(colscd['sh_bus'], 3, right=False)
bus_quart[:10]
# Out:
# name
# Alabama A & M University               [0.0, 0.333)
# University of Alabama at Birmingham    [0.0, 0.333)
# Amridge University                     [0.0, 0.333)
# University of Alabama in Huntsville    [0.0, 0.333)
# Alabama State University               [0.0, 0.333)
# The University of Alabama              [0.0, 0.333)
# Central Alabama Community College      [0.0, 0.333)
# Athens State University                [0.0, 0.333)
# Auburn University at Montgomery        [0.0, 0.333)
# Auburn University                      [0.0, 0.333)
# Name: sh_bus, dtype: category
# Categories (3, interval[float64]): [[0.0, 0.333) < [0.333, 0.667) < [0.667, 1.001)]

# %% [markdown]
# Remember, cut returns a Categorical object. We can use this object as our key variable in a groupby.

# %%
earn_bus = colscd.groupby(bus_quart)['earn_10']

# %% [markdown]
# Notice that we have used a key variable that was not a column of the DataFrame 'colscd'. The key variable can be very general. McKinney covers some other kinds of key variables.
#
# We now have a DatFrameGroupedBy object. What is the distribution of institutions?

# %%
earn_bus.count()
# Out:
# sh_bus
# [0.0, 0.333)      3513
# [0.333, 0.667)     675
# [0.667, 1.001)     792
# Name: earn_10, dtype: int64

# %% [markdown]
# ### Several statistics at once
# Once we have grouped our data, we have been hitting it with methods to compute statistics: mean(), count(),...
#
# We now introduced the `agg( )` method, which lets us compute several moments at once --- you can even pass it a user defined function.

# %%
# This is the same as earn_bus.count()
earn_bus.agg('count')
# Out:
# sh_bus
# [0.0, 0.333)      3513
# [0.333, 0.667)     675
# [0.667, 1.001)     792
# Name: earn_10, dtype: int64

# %%
# But agg() lets us compute many stats at once
earn_bus.agg(['count', 'mean', 'median', 'std'])
# Out:
#                 count       mean   median        std
# sh_bus
# [0.0, 0.333)     3513  35156.732  34200.0  12982.761
# [0.333, 0.667)    675  30551.852  29000.0   8503.932
# [0.667, 1.001)    792  33015.152  27600.0  15809.740

# %% [markdown]
# Schools that focus on business outcomes don't seem to offer greater earnings opportunities.

# %% [markdown]
# ## Practice
# 1. Write a function that returns the average of the 5 largest elements of a Series (a column of a DataFrame). Name the function 'avg5'.

# %%
def avg5(series): 
    return series.sort_values(ascending = False).dropna()[0:5].mean()

# %% [markdown]
# 2. Test your function on column 'a' of the DataFrame defined below. The answer should be 8.

# %%
test = pd.DataFrame({'a':[1, 4, 6, 9, 10, 3, 7, 8], 'b':[2, 3, 4, 5, 6, 7, 8, 10] })

# %%
test["a"].agg(avg5)
# Out:
# 8.0

# %% [markdown]
# 3. Drop any observation that has 'debt_at_grad' == NaN
# 4. Compute the mean, median, and avg5  'debt_at_grad' by 'ownership'. Compute them all at once using `agg()`.

# %%
colscd2 = colscd.drop(colscd[colscd.debt_at_grad.isna()].index, axis = 0)
debt_summary = colscd2.groupby("ownership")["debt_at_grad"].agg(["mean", "median", avg5])
debt_summary
# Out:
#                         mean   median     avg5
# ownership
# Private nonprofit  22398.733  24788.0  43574.2
# Private profit     14349.837  10572.0  47185.7
# Public             14206.001  12000.0  34669.2
